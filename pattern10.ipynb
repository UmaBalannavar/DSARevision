# %% [markdown]
# <a href="https://colab.research.google.com/github/UmaBalannavar/DSARevision/blob/main/pattern10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=5
for i in range(n):
    print((i+1)*"*",end="")
    print()
for i in range(n):
    print((n-i-1)*"*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
